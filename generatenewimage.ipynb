# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
folders=os.listdir("train/")

# %%
datagen = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')

# %%
#print(folders)
path="train/"
p="generated_img"
os.mkdir(p)
for car_name in range(len(folders)):
    car_folder=folders[car_name]
    new_path=path+car_folder+"/"
    print(new_path)
    #print(os.listdir(new_path))
    fold=os.listdir(new_path)
    path_to_save_generated_img=p+"/"+car_folder
    os.mkdir(path_to_save_generated_img)
    for car_img in range(len(fold)):
        k=fold[car_img]
        new_new_path=new_path+k
        img=image.load_img(new_new_path,target_size=(224,224,3))
        x=image.img_to_array(img)
        x = x.reshape((1,) + x.shape)
        i=0
        
        for batch in datagen.flow(x, batch_size=1,save_to_dir=path_to_save_generated_img, save_prefix=car_folder, save_format='jpeg'):
            i += 1
            if i > 15:
                break
# Out:
# train/Acura Integra Type R 2001/
# train/Acura RL Sedan 2012/
# train/Acura TL Sedan 2012/
# train/Acura TL Type-S 2008/
# train/Acura TSX Sedan 2012/
# train/Acura ZDX Hatchback 2012/
# train/AM General Hummer SUV 2000/
# train/Aston Martin V8 Vantage Convertible 2012/
# train/Aston Martin V8 Vantage Coupe 2012/
# train/Aston Martin Virage Convertible 2012/
# train/Aston Martin Virage Coupe 2012/
# train/Audi 100 Sedan 1994/
# train/Audi 100 Wagon 1994/
# train/Audi A5 Coupe 2012/
# train/Audi R8 Coupe 2012/
# train/Audi RS 4 Convertible 2008/
# train/Audi S4 Sedan 2007/
# train/Audi S4 Sedan 2012/
# train/Audi S5 Convertible 2012/
# train/Audi S5 Coupe 2012/
# train/Audi S6 Sedan 2011/
# train/Audi TT Hatchback 2011/
# train/Audi TT RS Coupe 2012/
# train/Audi TTS Coupe 2012/
# train/Audi V8 Sedan 1994/
# train/Bentley Arnage Sedan 2009/
# train/Bentley Continental Flying Spur Sedan 2007/
# train/Bentley Continental GT Coupe 2007/
# train/Bentley Continental GT Coupe 2012/
# ...

# %%
import shutil

# %%
list_of_cars=os.listdir("generated_img/")

# %%
if not os.path.isdir("valimg"):
    os.mkdir("valimg")

# %%
for c in list_of_cars:
    p=os.path.join("valimg/",c)
    if not os.path.isdir(p):
        os.mkdir(p)

# %%
SPLIT = 0.8
for f in os.listdir("generated_img/"):
    path = "generated_img/"+f
    imgs = os.listdir(path)
    
    split_size = int(SPLIT*len(imgs))
    files_to_move = imgs[split_size:]
    #print(len(files_to_move))
    #print(files_to_move)
    for img_f in files_to_move:
        src = os.path.join(path,img_f)
        dest = os.path.join("valimg/"+f,img_f)
        shutil.move(src,dest)
